# %% [markdown]
# <a href="https://colab.research.google.com/github/tonyscan6003/CE6003/blob/master/Etivity_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Etivity 2: Deep Convolutional Neural Network on CIFAR-10 Dataset
#
# In this assignment, we will gain some practical experience of coding a deep convolutional neural network in Tensorflow. The simplest way to code a network is to use the High level Keras API within Tensorflow 2.5.
#
# ## (a) Introduction
#
#  In this assignment to reduce training time and computation, we will train our network using the simple [CIFAR10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset.
# ![link text](https://paperswithcode.com/media/datasets/CIFAR-10-0000000431-b71f61c0_U5n3Glr.jpg)
#
# The goal of this Etivity is to build and train your own Deep Convolutional Neural Network. This notebook contains standard keras/Tensorflow code to perform data processing, training set up and testing metrics, as outlined in the steps below. This will allow you to focus on developing the architecture & code for your network.
#
# 1. Load Dataset - We will import the CIFAR-10 Dataset using the Tensorflow Data Set API.
# 2. Prepare Data - We will slightly modify the dataset before it is sent to the model for training.
# 3. Model Coding - We will write code to build the model using the Tensorflow keras API.
#   * **You will code your neural network model in this section**
# 4. Compile Model - We will complile the model and verify that it has been correctly constructed.
# 5. Train Model - We will train the model using the imported dataset.
# 6. Test Model - We test the model on the training data and obtain a classification report and confusion matrix.
#
# The principal resource for understanding the basics of how to code & train Deep Convolutional Neural Network architectures in Tensorflow/keras are the Tensorflow tutorials. Tutorials on [image classification](https://www.tensorflow.org/tutorials/images/classification) and [data augmentation](https://www.tensorflow.org/tutorials/images/data_augmentation) are useful for this Etivity.

# %% [markdown]
# ## (b) Notes on Architecture selection & development
#
# A key task in this Etivity is selecting an appropriate architecture. You can base your archicture on any of the types seen in the lecture notes or published literature. It is however recommended to ensure you can get a standard CNN type architecture to successfully train before attempting a more complex architecture or adding further enhancements to your network to improve performance.
#    Many published networks are designed to work with larger sized input images (e.g. 224 x 224). Often large (e.g. 7 x 7) convolution kernels and pooling layers are first applied to the input image, which agressively reduce the spatial dimensions of the network. As the CIFAR-10 dataset only has 32 x 32 images, it is recommended that just an intial 3 x 3 convolution is applied to the input image (as shown in the figure below), which will preserve the spatial dimensions of the input, before any other layers are added. It is expected that as you add more layers to the network the spatial dimensions will reduce and there will also be a corresponding increase the number of channels of the output feature map. The architecture will end with a [global average pooling layer](https://arxiv.org/pdf/1312.4400.pdf) and a fully-connected layer (called a *dense* layer in Keras/Tensorflow) with softmax activation which gives us our 10 class predictions. A skeleton code has been provided for any general architure using this structure in section 3.
# ![link text](https://github.com/tonyscan6003/CE6003/blob/master/images/Architecture_outline.jpg?raw=true)

# %% [markdown]
# #House Keeping

# %%
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.preprocessing import image

# %%
from __future__ import print_function

# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, ZeroPadding2D, Add 
from tensorflow.keras.layers import GlobalAveragePooling2D,AveragePooling2D, Input, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.initializers import glorot_uniform

import numpy as np

# %% [markdown]
# To ensure this assignment runs as fast as possible, from the menu above select **Edit > Notebook settings** or **Runtime > Change runtime type** and select GPU as the Hardware accelerator option.
#
# Let's test that we are running using the GPU.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# #1. Load Dataset
#
# In this assignment, we will be using the [CIFAR-10 dataset](http://www.cs.toronto.edu/~kriz/cifar.htmlhttps://). CIFAR-10 is often used as a "Hello World" dataset that is often used to ensure a network architecture is working before moving on to training with more complex datasets.
#
# The CIFAR-10 dataset consists of 60,000 32x32 color images in 10 classes (airplane, automobile, **bird**, cat, deer, dog, frog, horse, ship, truck), with 6,000 images per class. There are 50,000 training images and 10,000 test images.
#
# We will use the [Tensorflow dataset](https://www.tensorflow.org/datasets/catalog/cifar10) API to download the CIFAR10 dataset.

# %%
batch_size = 32 # Default Batch size (can be adjusted)
H_trg =32       # Image Height (fixed)
W_trg =32       # image Width (fixed)

# Labels corresponding to categories
label_str = ('airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# We initally load the raw training/validation/test dataset
import tensorflow_datasets as tfds
ds,info= tfds.load("cifar10",with_info=True)

raw_train = tfds.load('cifar10', split='train[0%:90%]')
raw_val = tfds.load('cifar10', split='train[91%:100%]')
raw_test = tfds.load('cifar10', split='test')

# %% [markdown]
# # 2. Prepare Data
#
# After importing raw datasets using tfds load, we create an input pipeline that processes & batches this data before it is supplied to the model for training using the virtual machine GPU.

# %%
def data_pipe(image,label):
  image = tf.image.convert_image_dtype(image, tf.float32) # Cast and normalize the image to [0,1]
  image = image-0.5
  label = tf.cast(label, tf.float32)
  return image,label

# %%
def gen_tr_datasets(src_dataset):    
    # Define Datasets 
    #src_dataset = src_dataset.shuffle(num_train_examples) 
    tr_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    tr_dataset = tr_dataset.map(data_pipe)
    tr_dataset = tr_dataset.batch(batch_size) 
    return tr_dataset

def gen_val_datasets(src_dataset): 
    # Define Datasets 
    test_dataset = src_dataset.map(lambda x: (x['image'],x['label']))  
    test_dataset = test_dataset.map(data_pipe)
    test_dataset = test_dataset.batch(batch_size) 
    return test_dataset
# Generate the datasets
train_dataset = gen_tr_datasets(raw_train)
val_dataset = gen_val_datasets(raw_val)
test_dataset = gen_val_datasets(raw_test)

# %% [markdown]
# Plot some examples of the training dataset.

# %%
i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image, label in train_dataset.take(n_plots):  # Only take a single example
  # axarr[i].imshow(image[0,:,:,:]+128)
  axarr[i].imshow(image[0,:,:,:])
  axarr[i].axis('off')
  axarr[i].title.set_text(label_str[int(label[0])])
  i = i+1
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 3. Model Coding
#
# In this section You may develop your own model architecture to perform image recognition with the CIFAR-10 Dataset.
#
# There are some recommendations and helper code in this section that you may choose use, or you can also use your own approach to creating your architecture.
#
# Please Leave a note at the end of the notebook explaining your approach/results for the e-moderator.

# %% [markdown]
#
# ## Note 1: Keras Function/Sequential API
#
# Within Keras there are two API's for coding network models: Sequential and functional. You may have already used the [seqential model](https://https://www.tensorflow.org/guide/keras/sequential_model) to code basic artifical neural networks. The [functional model](https://www.tensorflow.org/guide/keras/functional) is more general and enables us to include feedforward paths which are required to code more advanced networks such as ResNet or DenseNet. The functional API has been used to code the helper functions repeating unit/top level skeleton detailed below.
#
# ## Note 2: Repeating Unit
#
# In many Deep architectures there will often be a repeating unit(s) that is composed of a sequence of layers, for example Conv,ReLU & Batch Normalisation. Specific layers can be turned on or off as required. This also allows experimentation of the entire architecture with/without specific layers (e.g. Batch Normalisation)  You may wish to create other combinations of layers or additional repeating units depending on your architecture.
#
# In the code cell below we can see an example of a `repeat_unit` function where the number of kernel filters and kernel size is specified. Batch Normalisation and activation layers can be turned on/off as required.
#
#  * Convolutional Layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
#  * Batch Normalization layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization)
#  * Activation layers are described [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Activation)

# %%
# Example of a Basic Repeating unit

def repeat_unit(inputs, num_channels=16, kernel_size=3,
                 strides=1, activation='relu', batch_normalization=False):
    """
    inputs: Input to repeat unit.
    num_channels: number of channels in convolution layer of repeat unit, nominally = 16
    kernel_size: number of kernels to use in convolution, nominally = 3
    strides: number of strides for kernel, nominally = 1
    activation: type of activation applied to output of convolution, nominally ReLU. 
    x = output of repeat_unit
    """
    conv = Conv2D(num_channels, kernel_size=kernel_size, strides=strides, padding='same',
                  kernel_initializer='he_normal')
    x = conv(inputs)
    
    if activation is not None:
        x = Activation(activation)(x)

    if batch_normalization:
        x = BatchNormalization()(x)

    return x

# %% [markdown]
# ## Note 3: Top Level
#
# In the code cell below, an incomplete skeleton function is provided for your top level.
# * This uses the Keras functional API
# * A single repeating unit which does not reduce the spatial dimensions of the input is placed at the top of the stack. You can change the number of channels/kernel size to suit your own architecture.
# * You can add your own layers/repeating units etc to build your own architecture with the function.
# * At the end of the stack we add a [global average pooling layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GlobalAveragePooling2D) and fully connected [(Dense)](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) layer with softmax activation. (Alternatively to the Global Average pooling Dense layers can be used, this approach uses more parameter (memory) and is commonly seen in earlier Deeep Learning architectures such as AlexNet)

# %%
def data_augmentation (data_input) :

  augmented_data = tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal",input_shape=(200,3))(data_input)
  augmented_data = tf.keras.layers.experimental.preprocessing.RandomRotation(0.2)(augmented_data)
  augmented_data = tf.keras.layers.experimental.preprocessing.RandomZoom(0.2) (augmented_data)

  return augmented_data

# %%
def identity_block(inputs, num_channels=[16,16,16], kernel_size=3, activation='relu', batch_normalization= True) :
    c1, c2, c3 = num_channels

    X_shortcut = inputs

    x = repeat_unit(inputs=inputs, num_channels=c1, kernel_size=1, batch_normalization=True) 
    x = repeat_unit(inputs=x, num_channels=c2, kernel_size=kernel_size, batch_normalization=True)
    x = repeat_unit(inputs=x, num_channels=c3, kernel_size=1, batch_normalization=True, activation=None)

    x = Add()([x, X_shortcut])        
    x = Activation('relu')(x)
    return x

# %%
def convolution_block(inputs, num_channels=[16,16,16], s=2, kernel_size=3, activation='relu') :
    c1, c2, c3 = num_channels

    X_shortcut = inputs

    x = repeat_unit(inputs=inputs, num_channels=c1, kernel_size=1, batch_normalization=True)
    x = repeat_unit(inputs=x, num_channels=c2, kernel_size=kernel_size, batch_normalization=True) 
    x = repeat_unit(inputs=x, num_channels=c3, kernel_size=1, batch_normalization=True, activation=None) 

    X_shortcut = repeat_unit(inputs=X_shortcut, num_channels=c3, kernel_size=1, batch_normalization=True, activation=None)

    x = Add()([x, X_shortcut])        
    x = Activation('relu')(x)
    return x

# %%
def network_top(input_shape,num_classes=10):
    """
    input Shape: (Define H,W, no. channels) of network input
                 used in Input definition below
    num_classes: Default = 10, sets output classes of network,
                 set to same no. of classes as CIFAR 10 Dataset 
    model:       keras Model returned by this function.                          
    """
       
    # Define input of model
    inputs = Input(shape=input_shape)

    # Add First repeating Unit
    # x = repeat_unit(inputs=inputs, num_channels=12)
  

   ######## Add more layers/repeating units to build your Architecture here ##################  
   # https://towardsdatascience.com/extract-features-visualize-filters-and-feature-maps-in-vgg16-and-vgg19-cnn-models-d2da6333edd0
  #  https://machinelearningknowledge.ai/keras-implementation-of-resnet-50-architecture-from-scratch/
    # Data augmentation    
    # inputs = data_augmentation(inputs)
#  ResNet50
    # x = ZeroPadding2D((3, 3))(inputs)
    x = repeat_unit(inputs=inputs, num_channels=64,kernel_size=7,strides=2)
    x = MaxPooling2D((3, 3), strides=2)(x)

    x = convolution_block(inputs=x, num_channels=[64, 64, 256], s=1, kernel_size=3)
    x = identity_block(inputs=x, num_channels=[64, 64, 256], kernel_size=3)
    x = identity_block(inputs=x, num_channels=[64, 64, 256], kernel_size=3)

    x = convolution_block(inputs=x, num_channels=[128, 128, 512], s=2, kernel_size=3)
    x = identity_block(inputs=x, num_channels=[128, 128, 512], kernel_size=3)
    x = identity_block(inputs=x, num_channels=[128, 128, 512], kernel_size=3)  

    x = convolution_block(inputs=x, num_channels=[256, 256, 1024], s=2, kernel_size=3)
    x = identity_block(inputs=x, num_channels=[256, 256, 1024], kernel_size=3)
    x = identity_block(inputs=x, num_channels=[256, 256, 1024], kernel_size=3)        
    x = identity_block(inputs=x, num_channels=[256, 256, 1024], kernel_size=3)
    x = identity_block(inputs=x, num_channels=[256, 256, 1024], kernel_size=3) 
    x = identity_block(inputs=x, num_channels=[256, 256, 1024], kernel_size=3)

    x = convolution_block(inputs=x, num_channels=[512, 512, 2048], s=2, kernel_size=3)
    x = identity_block(inputs=x, num_channels=[512, 512, 2048], kernel_size=3)
    x = identity_block(inputs=x, num_channels=[512, 512, 2048], kernel_size=3)    

   ######## End Add more layers/repeating units to build your Architecture here ################## 

    # Add final stages. (Ensure that you call the output of the very last layer outputs)
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(x)

    # Model definition
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# https://cnvrg.io/cnn-tensorflow/?gclid=CjwKCAiAp8iMBhAqEiwAJb94zwWEL9kLN5La-XcINL_CJjPRrsx9JG9is6LkiHnkWzRdUPHQgm1tLxoCUIAQAvD_BwE
# # 64%

#     x = repeat_unit(inputs=inputs, num_channels=32)
#     x = MaxPooling2D((2, 2), strides=2)(x)

#     x = repeat_unit(inputs=inputs, num_channels=32)
#     x = MaxPooling2D((2, 2), strides=2)(x)
#     x = Dropout(0.25)(x)

#     x = repeat_unit(inputs=inputs, num_channels=64)
#     x = MaxPooling2D((2, 2), strides=2)(x)
#     x = Dropout(0.25)(x)
   


#     x = Flatten()(x)
#     x = Dense(128, activation="relu")(x)
#     x = Dropout(0.2)(x)

# %% [markdown]
# # 4. Compile the Model
# Now that we have defined our functions to create the model, we'll instantiate the model and compile it.  Note that the compiling step in Keras, also configures the model for training. We define  loss function, the optimizer and metrics.
#
# Note the use here of [Sparse Categorical Crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy). This loss function allows us to input integer values for true classes. With the regular categorical cross entropy loss function the supplied labels must be frist converted to a one-hot representation,  but this special loss function allows us to avoid manually converting to the one-hot representation.

# %%
input_shape = (32,32,3)
model = network_top(input_shape=input_shape)
model.compile(loss='SparseCategoricalCrossentropy', optimizer=Adam(), metrics=['accuracy'])
model.summary()

# Uncomment the following line to plot the model visually - warning this may be quite large!
# keras.utils.plot_model(model, dpi=48)
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_41 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  conv2d_447 (Conv2D)            (None, 16, 16, 64)   9472        ['input_41[0][0]']
#
#  activation_426 (Activation)    (None, 16, 16, 64)   0           ['conv2d_447[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 7, 7, 64)    0           ['activation_426[0][0]']
#  )
#
#  conv2d_448 (Conv2D)            (None, 7, 7, 64)     4160        ['max_pooling2d_20[0][0]']
#
#  activation_427 (Activation)    (None, 7, 7, 64)     0           ['conv2d_448[0][0]']
#
#  batch_normalization_440 (Batch  (None, 7, 7, 64)    256         ['activation_427[0][0]']
#  Normalization)
#
#  conv2d_449 (Conv2D)            (None, 7, 7, 64)     36928       ['batch_normalization_440[0][0]']
#
#  activation_428 (Activation)    (None, 7, 7, 64)     0           ['conv2d_449[0][0]']
#
#  batch_normalization_441 (Batch  (None, 7, 7, 64)    256         ['activation_428[0][0]']
#  Normalization)
#
#  conv2d_450 (Conv2D)            (None, 7, 7, 256)    16640       ['batch_normalization_441[0][0]']
#
#  conv2d_451 (Conv2D)            (None, 7, 7, 256)    16640       ['max_pooling2d_20[0][0]']
#
#  batch_normalization_442 (Batch  (None, 7, 7, 256)   1024        ['conv2d_450[0][0]']
#  Normalization)
#
#  batch_normalization_443 (Batch  (None, 7, 7, 256)   1024        ['conv2d_451[0][0]']
#  Normalization)
#
#  add_49 (Add)                   (None, 7, 7, 256)    0           ['batch_normalization_442[0][0]',
#                                                                   'batch_normalization_443[0][0]']
#
#  activation_429 (Activation)    (None, 7, 7, 256)    0           ['add_49[0][0]']
#
#  conv2d_452 (Conv2D)            (None, 7, 7, 64)     16448       ['activation_429[0][0]']
#
#  activation_430 (Activation)    (None, 7, 7, 64)     0           ['conv2d_452[0][0]']
#
#  batch_normalization_444 (Batch  (None, 7, 7, 64)    256         ['activation_430[0][0]']
#  Normalization)
#
#  conv2d_453 (Conv2D)            (None, 7, 7, 64)     36928       ['batch_normalization_444[0][0]']
#
#  activation_431 (Activation)    (None, 7, 7, 64)     0           ['conv2d_453[0][0]']
#
#  batch_normalization_445 (Batch  (None, 7, 7, 64)    256         ['activation_431[0][0]']
#  Normalization)
#
#  conv2d_454 (Conv2D)            (None, 7, 7, 256)    16640       ['batch_normalization_445[0][0]']
#
#  batch_normalization_446 (Batch  (None, 7, 7, 256)   1024        ['conv2d_454[0][0]']
#  Normalization)
#
#  add_50 (Add)                   (None, 7, 7, 256)    0           ['batch_normalization_446[0][0]',
#                                                                   'activation_429[0][0]']
#
#  activation_432 (Activation)    (None, 7, 7, 256)    0           ['add_50[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 7, 7, 64)     16448       ['activation_432[0][0]']
#
#  activation_433 (Activation)    (None, 7, 7, 64)     0           ['conv2d_455[0][0]']
#
#  batch_normalization_447 (Batch  (None, 7, 7, 64)    256         ['activation_433[0][0]']
#  Normalization)
#
#  conv2d_456 (Conv2D)            (None, 7, 7, 64)     36928       ['batch_normalization_447[0][0]']
#
#  activation_434 (Activation)    (None, 7, 7, 64)     0           ['conv2d_456[0][0]']
#
#  batch_normalization_448 (Batch  (None, 7, 7, 64)    256         ['activation_434[0][0]']
#  Normalization)
#
#  conv2d_457 (Conv2D)            (None, 7, 7, 256)    16640       ['batch_normalization_448[0][0]']
#
#  batch_normalization_449 (Batch  (None, 7, 7, 256)   1024        ['conv2d_457[0][0]']
#  Normalization)
#
#  add_51 (Add)                   (None, 7, 7, 256)    0           ['batch_normalization_449[0][0]',
#                                                                   'activation_432[0][0]']
#
#  activation_435 (Activation)    (None, 7, 7, 256)    0           ['add_51[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 7, 7, 128)    32896       ['activation_435[0][0]']
#
#  activation_436 (Activation)    (None, 7, 7, 128)    0           ['conv2d_458[0][0]']
#
#  batch_normalization_450 (Batch  (None, 7, 7, 128)   512         ['activation_436[0][0]']
#  Normalization)
#
#  conv2d_459 (Conv2D)            (None, 7, 7, 128)    147584      ['batch_normalization_450[0][0]']
#
#  activation_437 (Activation)    (None, 7, 7, 128)    0           ['conv2d_459[0][0]']
#
#  batch_normalization_451 (Batch  (None, 7, 7, 128)   512         ['activation_437[0][0]']
#  Normalization)
#
#  conv2d_460 (Conv2D)            (None, 7, 7, 512)    66048       ['batch_normalization_451[0][0]']
#
#  conv2d_461 (Conv2D)            (None, 7, 7, 512)    131584      ['activation_435[0][0]']
#
#  batch_normalization_452 (Batch  (None, 7, 7, 512)   2048        ['conv2d_460[0][0]']
#  Normalization)
#
#  batch_normalization_453 (Batch  (None, 7, 7, 512)   2048        ['conv2d_461[0][0]']
#  Normalization)
#
#  add_52 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_452[0][0]',
#                                                                   'batch_normalization_453[0][0]']
#
#  activation_438 (Activation)    (None, 7, 7, 512)    0           ['add_52[0][0]']
#
#  conv2d_462 (Conv2D)            (None, 7, 7, 128)    65664       ['activation_438[0][0]']
#
#  activation_439 (Activation)    (None, 7, 7, 128)    0           ['conv2d_462[0][0]']
#
#  batch_normalization_454 (Batch  (None, 7, 7, 128)   512         ['activation_439[0][0]']
#  Normalization)
#
#  conv2d_463 (Conv2D)            (None, 7, 7, 128)    147584      ['batch_normalization_454[0][0]']
#
#  activation_440 (Activation)    (None, 7, 7, 128)    0           ['conv2d_463[0][0]']
#
#  batch_normalization_455 (Batch  (None, 7, 7, 128)   512         ['activation_440[0][0]']
#  Normalization)
#
#  conv2d_464 (Conv2D)            (None, 7, 7, 512)    66048       ['batch_normalization_455[0][0]']
#
#  batch_normalization_456 (Batch  (None, 7, 7, 512)   2048        ['conv2d_464[0][0]']
#  Normalization)
#
#  add_53 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_456[0][0]',
#                                                                   'activation_438[0][0]']
#
#  activation_441 (Activation)    (None, 7, 7, 512)    0           ['add_53[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 7, 7, 128)    65664       ['activation_441[0][0]']
#
#  activation_442 (Activation)    (None, 7, 7, 128)    0           ['conv2d_465[0][0]']
#
#  batch_normalization_457 (Batch  (None, 7, 7, 128)   512         ['activation_442[0][0]']
#  Normalization)
#
#  conv2d_466 (Conv2D)            (None, 7, 7, 128)    147584      ['batch_normalization_457[0][0]']
#
#  activation_443 (Activation)    (None, 7, 7, 128)    0           ['conv2d_466[0][0]']
#
#  batch_normalization_458 (Batch  (None, 7, 7, 128)   512         ['activation_443[0][0]']
#  Normalization)
#
#  conv2d_467 (Conv2D)            (None, 7, 7, 512)    66048       ['batch_normalization_458[0][0]']
#
#  batch_normalization_459 (Batch  (None, 7, 7, 512)   2048        ['conv2d_467[0][0]']
#  Normalization)
#
#  add_54 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_459[0][0]',
#                                                                   'activation_441[0][0]']
#
#  activation_444 (Activation)    (None, 7, 7, 512)    0           ['add_54[0][0]']
#
#  conv2d_468 (Conv2D)            (None, 7, 7, 256)    131328      ['activation_444[0][0]']
#
#  activation_445 (Activation)    (None, 7, 7, 256)    0           ['conv2d_468[0][0]']
#
#  batch_normalization_460 (Batch  (None, 7, 7, 256)   1024        ['activation_445[0][0]']
#  Normalization)
#
#  conv2d_469 (Conv2D)            (None, 7, 7, 256)    590080      ['batch_normalization_460[0][0]']
#
#  activation_446 (Activation)    (None, 7, 7, 256)    0           ['conv2d_469[0][0]']
#
#  batch_normalization_461 (Batch  (None, 7, 7, 256)   1024        ['activation_446[0][0]']
#  Normalization)
#
#  conv2d_470 (Conv2D)            (None, 7, 7, 1024)   263168      ['batch_normalization_461[0][0]']
#
#  conv2d_471 (Conv2D)            (None, 7, 7, 1024)   525312      ['activation_444[0][0]']
#
#  batch_normalization_462 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_470[0][0]']
#  Normalization)
#
#  batch_normalization_463 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_471[0][0]']
#  Normalization)
#
#  add_55 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_462[0][0]',
#                                                                   'batch_normalization_463[0][0]']
#
#  activation_447 (Activation)    (None, 7, 7, 1024)   0           ['add_55[0][0]']
#
#  conv2d_472 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_447[0][0]']
#
#  activation_448 (Activation)    (None, 7, 7, 256)    0           ['conv2d_472[0][0]']
#
#  batch_normalization_464 (Batch  (None, 7, 7, 256)   1024        ['activation_448[0][0]']
#  Normalization)
#
#  conv2d_473 (Conv2D)            (None, 7, 7, 256)    590080      ['batch_normalization_464[0][0]']
#
#  activation_449 (Activation)    (None, 7, 7, 256)    0           ['conv2d_473[0][0]']
#
#  batch_normalization_465 (Batch  (None, 7, 7, 256)   1024        ['activation_449[0][0]']
#  Normalization)
#
#  conv2d_474 (Conv2D)            (None, 7, 7, 1024)   263168      ['batch_normalization_465[0][0]']
#
#  batch_normalization_466 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_474[0][0]']
#  Normalization)
#
#  add_56 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_466[0][0]',
#                                                                   'activation_447[0][0]']
#
#  activation_450 (Activation)    (None, 7, 7, 1024)   0           ['add_56[0][0]']
#
#  conv2d_475 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_450[0][0]']
#
#  activation_451 (Activation)    (None, 7, 7, 256)    0           ['conv2d_475[0][0]']
#
#  batch_normalization_467 (Batch  (None, 7, 7, 256)   1024        ['activation_451[0][0]']
#  Normalization)
#
#  conv2d_476 (Conv2D)            (None, 7, 7, 256)    590080      ['batch_normalization_467[0][0]']
#
#  activation_452 (Activation)    (None, 7, 7, 256)    0           ['conv2d_476[0][0]']
#
#  batch_normalization_468 (Batch  (None, 7, 7, 256)   1024        ['activation_452[0][0]']
#  Normalization)
#
#  conv2d_477 (Conv2D)            (None, 7, 7, 1024)   263168      ['batch_normalization_468[0][0]']
#
#  batch_normalization_469 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_477[0][0]']
#  Normalization)
#
#  add_57 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_469[0][0]',
#                                                                   'activation_450[0][0]']
#
#  activation_453 (Activation)    (None, 7, 7, 1024)   0           ['add_57[0][0]']
#
#  conv2d_478 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_453[0][0]']
#
#  activation_454 (Activation)    (None, 7, 7, 256)    0           ['conv2d_478[0][0]']
#
#  batch_normalization_470 (Batch  (None, 7, 7, 256)   1024        ['activation_454[0][0]']
#  Normalization)
#
#  conv2d_479 (Conv2D)            (None, 7, 7, 256)    590080      ['batch_normalization_470[0][0]']
#
#  activation_455 (Activation)    (None, 7, 7, 256)    0           ['conv2d_479[0][0]']
#
#  batch_normalization_471 (Batch  (None, 7, 7, 256)   1024        ['activation_455[0][0]']
#  Normalization)
#
#  conv2d_480 (Conv2D)            (None, 7, 7, 1024)   263168      ['batch_normalization_471[0][0]']
#
#  batch_normalization_472 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_480[0][0]']
#  Normalization)
#
#  add_58 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_472[0][0]',
#                                                                   'activation_453[0][0]']
#
#  activation_456 (Activation)    (None, 7, 7, 1024)   0           ['add_58[0][0]']
#
#  conv2d_481 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_456[0][0]']
#
#  activation_457 (Activation)    (None, 7, 7, 256)    0           ['conv2d_481[0][0]']
#
#  batch_normalization_473 (Batch  (None, 7, 7, 256)   1024        ['activation_457[0][0]']
#  Normalization)
#
#  conv2d_482 (Conv2D)            (None, 7, 7, 256)    590080      ['batch_normalization_473[0][0]']
#
#  activation_458 (Activation)    (None, 7, 7, 256)    0           ['conv2d_482[0][0]']
#
#  batch_normalization_474 (Batch  (None, 7, 7, 256)   1024        ['activation_458[0][0]']
#  Normalization)
#
#  conv2d_483 (Conv2D)            (None, 7, 7, 1024)   263168      ['batch_normalization_474[0][0]']
#
#  batch_normalization_475 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_483[0][0]']
#  Normalization)
#
#  add_59 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_475[0][0]',
#                                                                   'activation_456[0][0]']
#
#  activation_459 (Activation)    (None, 7, 7, 1024)   0           ['add_59[0][0]']
#
#  conv2d_484 (Conv2D)            (None, 7, 7, 256)    262400      ['activation_459[0][0]']
#
#  activation_460 (Activation)    (None, 7, 7, 256)    0           ['conv2d_484[0][0]']
#
#  batch_normalization_476 (Batch  (None, 7, 7, 256)   1024        ['activation_460[0][0]']
#  Normalization)
#
#  conv2d_485 (Conv2D)            (None, 7, 7, 256)    590080      ['batch_normalization_476[0][0]']
#
#  activation_461 (Activation)    (None, 7, 7, 256)    0           ['conv2d_485[0][0]']
#
#  batch_normalization_477 (Batch  (None, 7, 7, 256)   1024        ['activation_461[0][0]']
#  Normalization)
#
#  conv2d_486 (Conv2D)            (None, 7, 7, 1024)   263168      ['batch_normalization_477[0][0]']
#
#  batch_normalization_478 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_486[0][0]']
#  Normalization)
#
#  add_60 (Add)                   (None, 7, 7, 1024)   0           ['batch_normalization_478[0][0]',
#                                                                   'activation_459[0][0]']
#
#  activation_462 (Activation)    (None, 7, 7, 1024)   0           ['add_60[0][0]']
#
#  conv2d_487 (Conv2D)            (None, 7, 7, 512)    524800      ['activation_462[0][0]']
#
#  activation_463 (Activation)    (None, 7, 7, 512)    0           ['conv2d_487[0][0]']
#
#  batch_normalization_479 (Batch  (None, 7, 7, 512)   2048        ['activation_463[0][0]']
#  Normalization)
#
#  conv2d_488 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_479[0][0]']
#
#  activation_464 (Activation)    (None, 7, 7, 512)    0           ['conv2d_488[0][0]']
#
#  batch_normalization_480 (Batch  (None, 7, 7, 512)   2048        ['activation_464[0][0]']
#  Normalization)
#
#  conv2d_489 (Conv2D)            (None, 7, 7, 2048)   1050624     ['batch_normalization_480[0][0]']
#
#  conv2d_490 (Conv2D)            (None, 7, 7, 2048)   2099200     ['activation_462[0][0]']
#
#  batch_normalization_481 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_489[0][0]']
#  Normalization)
#
#  batch_normalization_482 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_490[0][0]']
#  Normalization)
#
#  add_61 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_481[0][0]',
#                                                                   'batch_normalization_482[0][0]']
#
#  activation_465 (Activation)    (None, 7, 7, 2048)   0           ['add_61[0][0]']
#
#  conv2d_491 (Conv2D)            (None, 7, 7, 512)    1049088     ['activation_465[0][0]']
#
#  activation_466 (Activation)    (None, 7, 7, 512)    0           ['conv2d_491[0][0]']
#
#  batch_normalization_483 (Batch  (None, 7, 7, 512)   2048        ['activation_466[0][0]']
#  Normalization)
#
#  conv2d_492 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_483[0][0]']
#
#  activation_467 (Activation)    (None, 7, 7, 512)    0           ['conv2d_492[0][0]']
#
#  batch_normalization_484 (Batch  (None, 7, 7, 512)   2048        ['activation_467[0][0]']
#  Normalization)
#
#  conv2d_493 (Conv2D)            (None, 7, 7, 2048)   1050624     ['batch_normalization_484[0][0]']
#
#  batch_normalization_485 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_493[0][0]']
#  Normalization)
#
#  add_62 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_485[0][0]',
#                                                                   'activation_465[0][0]']
#
#  activation_468 (Activation)    (None, 7, 7, 2048)   0           ['add_62[0][0]']
#
#  conv2d_494 (Conv2D)            (None, 7, 7, 512)    1049088     ['activation_468[0][0]']
#
#  activation_469 (Activation)    (None, 7, 7, 512)    0           ['conv2d_494[0][0]']
#
#  batch_normalization_486 (Batch  (None, 7, 7, 512)   2048        ['activation_469[0][0]']
#  Normalization)
#
#  conv2d_495 (Conv2D)            (None, 7, 7, 512)    2359808     ['batch_normalization_486[0][0]']
#
#  activation_470 (Activation)    (None, 7, 7, 512)    0           ['conv2d_495[0][0]']
#
#  batch_normalization_487 (Batch  (None, 7, 7, 512)   2048        ['activation_470[0][0]']
#  Normalization)
#
#  conv2d_496 (Conv2D)            (None, 7, 7, 2048)   1050624     ['batch_normalization_487[0][0]']
#
#  batch_normalization_488 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_496[0][0]']
#  Normalization)
#
#  add_63 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_488[0][0]',
#                                                                   'activation_468[0][0]']
#
#  activation_471 (Activation)    (None, 7, 7, 2048)   0           ['add_63[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['activation_471[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 10)           20490       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 23,325,578
# Trainable params: 23,274,122
# Non-trainable params: 51,456
# __________________________________________________________________________________________________

# %% [markdown]
# # 5. Model Training
#
# We will now train the complied model on the cifar10 dataset using the tensorflow keras `model.fit` method.

# %%
from tensorflow.keras.callbacks import EarlyStopping
callbacks = [
             EarlyStopping(patience=20)
]

# %%
# epochs =55
epochs = 600
history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=val_dataset,callbacks=callbacks)
# Out:
# Epoch 1/600
# 1407/1407 [==============================] - 82s 58ms/step - loss: 0.4682 - accuracy: 0.8357 - val_loss: 0.9902 - val_accuracy: 0.7096
# Epoch 2/600
# 1407/1407 [==============================] - 82s 58ms/step - loss: 0.3965 - accuracy: 0.8598 - val_loss: 1.0275 - val_accuracy: 0.7144
# Epoch 3/600
# 1407/1407 [==============================] - 82s 58ms/step - loss: 0.3292 - accuracy: 0.8846 - val_loss: 1.0788 - val_accuracy: 0.6973
# Epoch 4/600
# 1407/1407 [==============================] - 82s 58ms/step - loss: 0.2843 - accuracy: 0.8994 - val_loss: 0.9490 - val_accuracy: 0.7522
# Epoch 5/600
# 1407/1407 [==============================] - 82s 58ms/step - loss: 0.2344 - accuracy: 0.9173 - val_loss: 1.0504 - val_accuracy: 0.7360
# Epoch 6/600
# 1407/1407 [==============================] - 82s 58ms/step - loss: 0.2041 - accuracy: 0.9278 - val_loss: 1.0884 - val_accuracy: 0.7456
# Epoch 7/600
# 1407/1407 [==============================] - 82s 58ms/step - loss: 0.1707 - accuracy: 0.9382 - val_loss: 1.0868 - val_accuracy: 0.7456
# Epoch 8/600
# 1407/1407 [==============================] - 82s 58ms/step - loss: 0.1600 - accuracy: 0.9439 - val_loss: 1.1079 - val_accuracy: 0.7489
# Epoch 9/600
# 1407/1407 [==============================] - 81s 58ms/step - loss: 0.1300 - accuracy: 0.9539 - val_loss: 1.1403 - val_accuracy: 0.7522
# Epoch 10/600
# 1407/1407 [==============================] - 81s 58ms/step - loss: 0.1244 - accuracy: 0.9553 - val_loss: 1.1396 - val_accuracy: 0.7493
# Epoch 11/600
# 1407/1407 [==============================] - 81s 58ms/step - loss: 0.1104 - accuracy: 0.9611 - val_loss: 1.1942 - val_accuracy: 0.7602
# Epoch 12/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.1081 - accuracy: 0.9615 - val_loss: 1.2904 - val_accuracy: 0.7491
# Epoch 13/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0952 - accuracy: 0.9662 - val_loss: 1.3891 - val_accuracy: 0.7580
# Epoch 14/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0832 - accuracy: 0.9704 - val_loss: 1.1671 - val_accuracy: 0.7629
# Epoch 15/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0858 - accuracy: 0.9703 - val_loss: 1.1431 - val_accuracy: 0.7716
# Epoch 16/600
# 1407/1407 [==============================] - 81s 58ms/step - loss: 0.0771 - accuracy: 0.9735 - val_loss: 1.2047 - val_accuracy: 0.7780
# Epoch 17/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0748 - accuracy: 0.9745 - val_loss: 1.1169 - val_accuracy: 0.7782
# Epoch 18/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0701 - accuracy: 0.9757 - val_loss: 1.0869 - val_accuracy: 0.7920
# Epoch 19/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0632 - accuracy: 0.9778 - val_loss: 1.1709 - val_accuracy: 0.7824
# Epoch 20/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0628 - accuracy: 0.9783 - val_loss: 1.1755 - val_accuracy: 0.7884
# Epoch 21/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0623 - accuracy: 0.9786 - val_loss: 1.3063 - val_accuracy: 0.7684
# Epoch 22/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0520 - accuracy: 0.9819 - val_loss: 1.2362 - val_accuracy: 0.7856
# Epoch 23/600
# 1407/1407 [==============================] - 81s 57ms/step - loss: 0.0562 - accuracy: 0.9800 - val_loss: 1.2907 - val_accuracy: 0.7753
# Epoch 24/600
# 1407/1407 [==============================] - 81s 58ms/step - loss: 0.0530 - accuracy: 0.9810 - val_loss: 1.2389 - val_accuracy: 0.7769

# %% [markdown]
# We will plot the loss and accuracy for the training and validation data sets.

# %%
print(history.history.keys())
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,2.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # 6. Model Testing
# We will iterate through the test data and analyse the results using tools from sklearn. We create a classification report, a confusion matrix and also plot a few examples from the test set.

# %% [markdown]
# Iterate through n_test batches and store the predicted and ground truth labels in numpy arrays.

# %%
n_test = 100 # number of batches to use
store_predictions = []
store_labels = []
for image_batch,label_batch in test_dataset.take(n_test):
    predictions = model.predict_on_batch(image_batch) 
    predictions = tf.math.argmax(predictions,axis=1)
    store_predictions.append(predictions)
    store_labels.append(label_batch)
y_pred = np.squeeze(np.reshape(store_predictions,(1,n_test*batch_size)))
y_true = np.squeeze(np.reshape(store_labels,(1,n_test*batch_size)))

# %% [markdown]
# Create and plot a confusion matrix.

# %%
#https://scikit-learn.org/0.16/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred)
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_str))
    plt.xticks(tick_marks, label_str, rotation=45)
    plt.yticks(tick_marks, label_str)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

plot_confusion_matrix(cm)

# %% [markdown]
# Generate & print the classification report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=label_str))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.84      0.82      0.83       337
#   automobile       0.86      0.86      0.86       338
#         bird       0.80      0.70      0.75       306
#          cat       0.63      0.60      0.62       323
#         deer       0.72      0.85      0.77       297
#          dog       0.74      0.69      0.71       325
#         frog       0.79      0.90      0.84       307
#        horse       0.84      0.86      0.85       317
#         ship       0.90      0.89      0.90       326
#        truck       0.87      0.82      0.84       324
#
#     accuracy                           0.80      3200
#    macro avg       0.80      0.80      0.80      3200
# weighted avg       0.80      0.80      0.80      3200

# %% [markdown]
# Plot some test images and predicted labels.

# %%
#Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)
print(np.shape(predictions))
# Apply a sigmoid since our model returns logits
predictions = tf.math.argmax(predictions,axis=1)
print(np.shape(predictions))
print('Predictions:\n', predictions.numpy())


i=0
n_plots = 12 # number of plots
f, axarr = plt.subplots(1,n_plots,figsize=(20,10))

for image in image_batch[0:n_plots,:,:,:]:  # Only take a single example
  axarr[i].imshow(image[:,:,:]+0.5)
  axarr[i].axis('off')
  
  color = ('black' if predictions[i] == int(label_batch[i]) else 'red') 
  axarr[i].set_title(label_str[int(predictions[i])],fontsize='small', color=color)
  i = i+1
# Out:
# (32, 10)
# (32,)
# Predictions:
#  [7 0 6 9 5 1 7 8 5 4 7 2 7 9 6 0 0 8 7 9 4 6 3 5 3 8 6 8 1 8 6 0]

# %% [markdown]
# # Please Leave a note here explaining your approach/results for the e-moderator.

# %%
 Model: "model_1"
_________________________________________________________________
 Layer (type)                Output Shape              Param #   
=================================================================
 input_3 (InputLayer)        [(None, 32, 32, 3)]       0         
                                                                 
 conv2d_31 (Conv2D)          (None, 32, 32, 512)       14336     
                                                                 
 activation_31 (Activation)  (None, 32, 32, 512)       0         
                                                                 
 max_pooling2d_9 (MaxPooling  (None, 16, 16, 512)      0         
 2D)                                                             
                                                                 
 flatten_1 (Flatten)         (None, 131072)            0         
                                                                 
 dense_3 (Dense)             (None, 4096)              536875008 
                                                                 
 dense_4 (Dense)             (None, 256)               1048832   
                                                                 
 dense_5 (Dense)             (None, 10)                2570      
                                                                 
=================================================================
Total params: 537,940,746
Trainable params: 537,940,746
Non-trainable params: 0
_________________________________________________________________   
    
    
    x = repeat_unit(inputs=inputs, num_channels=64)
    x = repeat_unit(inputs=inputs, num_channels=64)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = repeat_unit(inputs=inputs, num_channels=128)
    x = repeat_unit(inputs=inputs, num_channels=128)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = repeat_unit(inputs=inputs, num_channels=256)
    x = repeat_unit(inputs=inputs, num_channels=256)
    x = repeat_unit(inputs=inputs, num_channels=256)
    x = repeat_unit(inputs=inputs, num_channels=256)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = repeat_unit(inputs=inputs, num_channels=512)
    x = repeat_unit(inputs=inputs, num_channels=512)
    x = repeat_unit(inputs=inputs, num_channels=512)
    x = repeat_unit(inputs=inputs, num_channels=512)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = repeat_unit(inputs=inputs, num_channels=512)
    x = repeat_unit(inputs=inputs, num_channels=512)
    x = repeat_unit(inputs=inputs, num_channels=512)
    x = repeat_unit(inputs=inputs, num_channels=512)
    x = MaxPooling2D(pool_size=(2,2))(x)

    x = Flatten()(x)
    x = Dense(4096, activation='relu')(x)
    x = Dense(256, activation='relu')(x)


Epoch 1/600
1407/1407 [==============================] - 73s 40ms/step - loss: 2.6312 - accuracy: 0.3489 - val_loss: 1.5200 - val_accuracy: 0.4133
Epoch 2/600
1407/1407 [==============================] - 56s 40ms/step - loss: 1.4148 - accuracy: 0.4668 - val_loss: 1.3324 - val_accuracy: 0.5051
Epoch 3/600
1407/1407 [==============================] - 56s 39ms/step - loss: 1.2700 - accuracy: 0.5299 - val_loss: 1.3368 - val_accuracy: 0.5198
Epoch 4/600
1407/1407 [==============================] - 56s 40ms/step - loss: 1.1603 - accuracy: 0.5762 - val_loss: 1.2869 - val_accuracy: 0.5382
Epoch 5/600
1407/1407 [==============================] - 56s 40ms/step - loss: 1.0713 - accuracy: 0.6106 - val_loss: 1.2939 - val_accuracy: 0.5456
Epoch 6/600
1407/1407 [==============================] - 56s 39ms/step - loss: 0.9883 - accuracy: 0.6420 - val_loss: 1.2758 - val_accuracy: 0.5604
Epoch 7/600
1407/1407 [==============================] - 56s 40ms/step - loss: 0.9183 - accuracy: 0.6667 - val_loss: 1.2715 - val_accuracy: 0.5760
Epoch 8/600
1407/1407 [==============================] - 56s 40ms/step - loss: 0.8520 - accuracy: 0.6915 - val_loss: 1.3280 - val_accuracy: 0.5796
Epoch 9/600
1407/1407 [==============================] - 55s 39ms/step - loss: 0.7975 - accuracy: 0.7124 - val_loss: 1.3935 - val_accuracy: 0.5807
